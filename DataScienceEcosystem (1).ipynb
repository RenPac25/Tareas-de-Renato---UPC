# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introducción
# En este notebook están los ejercicios finales del curso de Data Science, utilizando Markdown y Python. A través de este notebook se muestran conceptos básicos como lenguajes, bibliotecas, herramientas y ejemplos simples de operaciones aritméticas realizadas en código.

# %% [markdown]
# ## Lenguajes de la Ciencia de Datos
# Algunos de los lenguajes más relevantes son:
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. Julia

# %% [markdown]
# ## Bibliotecas de Ciencia de Datos
# Algunas de las bibliotecas que la Ciencia de datos usa son:
# - NumPy
# - Pandas
# - Matplotlib
# - Scikit-Learn
# - TensorFlow

# %% [markdown]
# ## Herramientas de Ciencia de Datos
#
# | Herramienta | Descripción |
# |-------------|-------------|
# | Jupyter Notebook | Entorno interactivo para programación |
# | RStudio | Entorno de desarrollo para R |
# | Visual Studio Code | Editor flexible para múltiples lenguajes |
# | GitHub | Control de versiones y colaboración |
# | Apache Spark | Procesamiento de grandes volúmenes de datos |

# %% [markdown]
# ## Ejemplos de Operaciones Aritméticas en Python
# A continuación se mostrarán ejemplos de operaciones aritméticas básicas como suma, multiplicación y conversión de unidades utilizando código en Python.

# %%
multiplicación = 8*7
multiplicación
# Out:
# 56

# %%
suma = 15+20
suma
# Out:
# 35

# %%
minutos = 200
horas = minutos/60
horas
# Out:
# 3.3333333333333335

# %%
objetivos = [
    "Aprender a usar Markdown",
    "Realizar operaciones básicas con Python",
    "Construir un cuaderno profesional en Jupyter",
    "Publicar el notebook en GitHub"
]
objetivos
# Out:
# ['Aprender a usar Markdown',
#  'Realizar operaciones básicas con Python',
#  'Construir un cuaderno profesional en Jupyter',
#  'Publicar el notebook en GitHub']

# %% [markdown]
# ## Autor
# *Renato Paolo Pacora Villanueva*
